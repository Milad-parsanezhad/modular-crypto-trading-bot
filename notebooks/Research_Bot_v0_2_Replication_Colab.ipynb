# %% [markdown]
# # Modular Crypto Research Bot v0.2 — Replication Lab
# Clean successor to the audited legacy Colab notebooks. Public data only; no live orders.
# Scientific gates: point-in-time features, no temporal backfill, no future-shift Ichimoku, explicit frictions, event sampling, triple-barrier labeling, and temporal purge.

# %%
# !rm -rf modular-crypto-trading-bot
# !git clone https://github.com/parsa314/modular-crypto-trading-bot.git
# %cd modular-crypto-trading-bot
# !python -m pip install -q -e '.[dev]'

# %%
# !pytest -q

# %%
# !python scripts/run_baseline.py --exchange coinex --symbol BTC/USDT --timeframe 4h --limit 3000 --fee-bps 10 --slippage-bps 2 --output artifacts/baseline_report.json

# %%
# !python scripts/run_replication_v02.py --exchange coinex --symbol BTC/USDT --timeframe 4h --limit 3000 --fee-bps 10 --slippage-bps 2 --output artifacts/replication_v02_report.json

# %%
import json
replication = json.load(open('artifacts/replication_v02_report.json'))
replication
