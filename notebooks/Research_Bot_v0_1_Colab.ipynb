# %% [markdown]
# # Modular Crypto Research Bot v0.1
# Runs a reproducible baseline on public market data. No API keys and no live orders.

# %%
# !git clone https://github.com/parsa314/modular-crypto-trading-bot.git
# %cd modular-crypto-trading-bot
# !python -m pip install -q -e '.[dev]'

# %%
# !pytest -q

# %%
# !python scripts/run_baseline.py --exchange coinex --symbol BTC/USDT --timeframe 4h --limit 2000 --fee-bps 10 --slippage-bps 2 --output artifacts/baseline_report.json

# %%
import json
report = json.load(open('artifacts/baseline_report.json'))
report['metrics']
