# %% [markdown]
# # Research Bot v0.3 — Data & Alpha Lab
# Historical data + Funding/Basis/Open Interest + Order Flow. Public data only; no live orders.

# %%
# !rm -rf modular-crypto-trading-bot
# !git clone https://github.com/parsa314/modular-crypto-trading-bot.git
# %cd modular-crypto-trading-bot
# !python -m pip install -q -e '.[dev]'

# %%
# !pytest -q

# %%
# !python scripts/run_alpha_data_v03.py --symbol BTC/USDT --bars 3000 --period 4hour --funding-days 365 --basis-days 30 --trade-pages 5 --output-dir artifacts/v03

# %%
import json, pandas as pd
report=json.load(open('artifacts/v03/v03_data_alpha_report.json'))
report

# %%
alpha=pd.read_csv('artifacts/v03/alpha_frame_v03.csv')
alpha.tail()
